# %%
from pyspark import StorageLevel
from pyspark.sql.types import *
import numpy as np
import json
from functools import reduce
hdfs_workdir = 'hdfs://192.180.3.43:9000/'
path_prefix = hdfs_workdir+ 'phone_detail/'
import time
fileall = hdfs_workdir+'edge_full.csv/*.csv'

# %%
def get_schema(schemaString,typeString):
    dict_getType = {'int':IntegerType(),'string':StringType(),'float':FloatType(),'bool':BooleanType()}
    fields = [StructField(field_name, dict_getType.get(Type), True) 
              for field_name,Type in zip(schemaString.split(' '),typeString.split(' '))]
    schema = StructType(fields)
    return schema

# %%
filepeople = hdfs_workdir+'people_full.csv/*.csv'

df_people = spark.read.csv(filepeople)

df_people.createOrReplaceTempView("people")

schema = get_schema('_c0','string')
rdd3 = sc.parallelize(BCoverdue.value).map(lambda x:(x,))
df_overdue = spark.createDataFrame(rdd3, schema=schema)

df_have = df_people.join(df_overdue,on='_c0')

df_have.createOrReplaceTempView("people_have")

df_have2 = spark.sql('select _c0,_c7,_c14 from people_have where _c14 == True')

df_have2.persist()

df_have2.show()

df_have2.count()

# %%
df_have2.show()
# Out:
# +-----------+---+----+
# |        _c0|_c7|_c14|
# +-----------+---+----+
# |13129610787|杨俊伟|true|
# |13143504061|杨溢强|true|
# |13166606295| 郭建|true|
# |13229558452|胡颂智|true|
# |13568006801|李忠禄|true|
# |13644542797| 李雪|true|
# |13701647102|陈建胜|true|
# |13707990743| 肖露|true|
# |13733899149| 李辰|true|
# |13929935461|高平英|true|
# |15034219598| 梁敏|true|
# |15100518669| 姚彬|true|
# |15832928789|孔云超|true|
# |15921334327| 刘猛|true|
# |17607656987|冯勤俊|true|
# |17717758695| 霍珺|true|
# |18007399091|屈晖朋|true|
# |18021798136|张成义|true|
# |18026885157|叶启荣|true|
# |18039452499|张豪豪|true|
# +-----------+---+----+
# only showing top 20 rows

# %%
rdd_raw = sc.textFile(fileall)

# %%
def process_func(x):
    items = x.split(',')
    return (items[0],items[1],int(items[2]),int(items[3]))
rdd1 = rdd_raw.map(process_func)

# %%
rdd2 = rdd1.map(lambda x:((x[0],x[1]),(x[2],x[3])))

# %%
rdd21 = rdd2.filter(lambda x:(x[0][0][:4]=='1370'))

# %%
rdd21.persist()
# Out:
# PythonRDD[12] at RDD at PythonRDD.scala:48

# %%
rdd21.count()
# Out:
# 203779

# %%
rdd21.take(10)
# Out:
# [(('13701647102', '18895354388'), (318, 1))]

# %%
def adjust_order(x):
    if x[0][0] > x[0][1]:
        return x
    else:
        return (x[0][1],x[0][0]),x[1]
# 调整主被叫顺服
rdd22 = rdd2.map(adjust_order)
rdd23 = rdd22.reduceByKey(lambda x,y:(x[0]+y[0],x[1]+y[1]))
def flat_func(x):
    return x,((x[0][1],x[0][0]),x[1])
rdd24 = rdd23.flatMap(flat_func)

# %%
rdd24.unpersist()
# Out:
# PythonRDD[6] at RDD at PythonRDD.scala:48

# %%
rdd25 = rdd24.groupBy(lambda x:x[0][0])

# %%
with open('overdue.json') as f:
    overdue_users = set(json.load(f).values())
BCoverdue = sc.broadcast(overdue_users)

# %%
def get_wrightv1(x):
    Shrink = 0.5
    k,d = x
    ct1 = np.log(np.array([b[1] for a,b in d.data])+1)
    total1 = np.sum(ct1)
    w1 = (ct1/total1).tolist()
    
#     ct2 = np.array([b[1] for a,b in d.data])
#     total2 = np.sum(ct2)
#     w2 = (ct2/total2).tolist()
    keys = [a for a,b in d.data]
    other_phone = set([y for x,y in keys])
    overdue_people = BCoverdue.value&other_phone
    if overdue_people:
        overdue_rate = sum([v for k,v in zip(keys,w1) if k[1] in overdue_people])
        Shrink_rate = Shrink + (1 - Shrink)/overdue_rate
        re_weight_func = lambda p,w:w*Shrink_rate if p in overdue_people else w*Shrink
        w2 = [re_weight_func(k[1],v) for k,v in zip(keys,w1)]
        return zip(keys,w1,w2)
    else:
        return zip(keys,w1,w1) 
    
    
    
rdd26 = rdd25.flatMap(get_wrightv1)

# %% [markdown]
# ###  Part2

# %%
rdd30 = rdd24.groupBy(lambda x:x[0][0])

# %%
rdd24.take(10)
# Out:
# [(('18924833436', '13702588622'), (39, 1)),
#  (('13702588622', '18924833436'), (39, 1)),
#  (('18687775572', '13708790042'), (130, 3)),
#  (('13708790042', '18687775572'), (130, 3)),
#  (('15937818161', '13700783066'), (29, 2)),
#  (('13700783066', '15937818161'), (29, 2)),
#  (('13807213332', '13707210119'), (69, 1)),
#  (('13707210119', '13807213332'), (69, 1)),
#  (('15051037288', '13706898889'), (87, 4)),
#  (('13706898889', '15051037288'), (87, 4))]

# %%
def stat_overdue(x):
    others = set([i[0][1] for i in x.data])
    overdue_people = BCoverdue.value&others
    over_num = len(overdue_people)
    if over_num > 0:
        over_calltime_mean = np.mean([i[1][0] for i in x.data])
        over_callcnt_mean = np.mean([i[1][1] for i in x.data])
        return over_num,over_calltime_mean,over_callcnt_mean
    else:
        return 0,0,0
    
rdd31 = rdd30.mapValues(stat_overdue)

# %%
rdd32 = rdd31.map(lambda x:)

# %%
rdd31.persist(StorageLevel(False,True,True,False,))
# Out:
# PythonRDD[11] at RDD at PythonRDD.scala:48

# %%
rdd31

# %%
hdfs_workdir
# Out:
# 'hdfs://192.180.3.43:9000/'

# %%
rdd31.saveAsTextFile(hdfs_workdir+'overdupeople.csv')

# %%
rdd31.take(10)

# %% [markdown]
# ## read

# %%
rdd4 = sc.textFile(hdfs_workdir+'overdupeople.csv')

# %%
rdd41 = rdd4.map(lambda x:eval(x))

# %%
rdd41.unpersist()
# Out:
# PythonRDD[29] at RDD at PythonRDD.scala:48

# %%
rdd42 = rdd41.sortBy(lambda x:x[1][0],ascending=False)
rdd42.persist()
rdd42.take(200)
# Out:
# [('13800138000', (26, 140.88188976377953, 2.9763779527559056)),
#  ('13800290309', (20, 63.455414012738856, 1.984076433121019)),
#  ('18626835024', (16, 62.22813688212928, 2.0)),
#  ('18601399426', (15, 226.89265536723164, 1.305084745762712)),
#  ('18605875045', (15, 61.717592592592595, 1.8935185185185186)),
#  ('18605874869', (15, 63.8390243902439, 1.8780487804878048)),
#  ('135********', (15, 1527.7892271662763, 20.379391100702577)),
#  ('18605874656', (15, 65.76442307692308, 2.014423076923077)),
#  ('18626834723', (15, 69.30555555555556, 2.1547619047619047)),
#  ('18605870470', (15, 59.18571428571428, 1.861904761904762)),
#  ('18626834743', (14, 68.23308270676692, 1.9323308270676691)),
#  ('18605874580', (12, 62.21465968586387, 1.8586387434554974)),
#  ('18657945344', (12, 70.61870503597122, 2.1870503597122304)),
#  ('13909281860', (12, 56.997142857142855, 1.2257142857142858)),
#  ('18605873641', (12, 57.027027027027025, 1.7837837837837838)),
#  ('18626832340', (12, 67.43542435424354, 1.881918819188192)),
#  ('18657947004', (12, 70.02941176470588, 2.2857142857142856)),
#  ('18605870740', (12, 53.029556650246306, 1.7044334975369457)),
#  ('18657938204', (12, 60.62626262626262, 2.025252525252525)),
#  ('18626839482', (12, 61.44074074074074, 1.9037037037037037)),
#  ('18626834613', (12, 63.21804511278196, 1.9887218045112782)),
#  ('18512006234', (12, 56.21637426900585, 1.695906432748538)),
#  ('18659034804', (12, 84.94142259414225, 2.414225941422594)),
#  ('18605872041', (12, 62.733333333333334, 1.9692307692307693)),
#  ('18657947064', (12, 72.21090909090908, 2.1672727272727275)),
#  ('18626831545', (11, 49.36, 1.624)),
#  ('137********', (11, 1394.944297082228, 16.456233421750664)),
#  ('18664999464', (11, 61.698412698412696, 1.746031746031746)),
#  ('18512006614', (11, 67.53191489361703, 1.946808510638298)),
#  ('18575205847', (11, 55.25190839694657, 1.6870229007633588)),
#  ('18605873490', (11, 64.46153846153847, 1.978021978021978)),
#  ('18657935644', (11, 65.70854271356784, 2.0050251256281406)),
#  ('18512006464', (11, 58.31794871794872, 1.7333333333333334)),
#  ('18698394634', (11, 66.68817204301075, 2.0376344086021505)),
#  ('18605878492', (11, 68.70967741935483, 2.036290322580645)),
#  ('18605872417', (11, 64.45744680851064, 1.898936170212766)),
#  ('18605875425', (11, 59.948113207547166, 1.8113207547169812)),
#  ('18657947124', (11, 66.48327137546468, 2.197026022304833)),
#  ('18659014834', (11, 62.98453608247423, 1.9175257731958764)),
#  ('18626831425', (11, 64.74789915966386, 1.8487394957983194)),
#  ('13524661289', (11, 116.77777777777777, 1.4747474747474747)),
#  ('18605871041', (11, 58.29326923076923, 1.8028846153846154)),
#  ('139********', (11, 1486.8021978021977, 14.340659340659341)),
#  ('18657939694', (11, 69.16312056737588, 2.152482269503546)),
#  ('18626836234', (11, 61.12156862745098, 1.9490196078431372)),
#  ('18605870471', (11, 58.4009900990099, 1.886138613861386)),
#  ('18605873420', (11, 62.691943127962084, 1.8151658767772512)),
#  ('18659814554', (11, 77.48275862068965, 2.2413793103448274)),
#  ('18664905473', (11, 64.89320388349515, 1.6601941747572815)),
#  ('136********', (11, 1327.3427835051546, 15.06701030927835)),
#  ('13028935999', (11, 81.38970588235294, 1.088235294117647)),
#  ('18605874950', (11, 61.21182266009852, 1.9211822660098523)),
#  ('18698394534', (11, 66.73737373737374, 1.904040404040404)),
#  ('18601355242', (11, 259.1025641025641, 1.3923076923076922)),
#  ('18659022470', (11, 80.75, 2.2916666666666665)),
#  ('18605871646', (11, 65.87128712871286, 1.99009900990099)),
#  ('18605872346', (11, 52.903225806451616, 1.7188940092165899)),
#  ('18602936174', (11, 79.53636363636363, 1.8272727272727274)),
#  ('18512006154', (11, 66.7239263803681, 2.0061349693251533)),
#  ('18650594154', (11, 78.60714285714286, 2.3125)),
#  ('18662753866', (10, 51.236559139784944, 2.1021505376344085)),
#  ('18605872415', (10, 58.127962085308056, 1.7677725118483412)),
#  ('18605878497', (10, 74.02510460251047, 2.1129707112970713)),
#  ('18657933934', (10, 66.54629629629629, 2.199074074074074)),
#  ('18625587094', (10, 56.49367088607595, 1.5063291139240507)),
#  ('18575233134', (10, 59.41428571428571, 1.8214285714285714)),
#  ('18657947114', (10, 67.02142857142857, 2.1714285714285713)),
#  ('18502804002', (10, 51.608333333333334, 1.6083333333333334)),
#  ('18657947374', (10, 68.41338582677166, 2.2244094488188977)),
#  ('18512006074', (10, 54.645348837209305, 1.7616279069767442)),
#  ('18657936144', (10, 61.5260663507109, 1.95260663507109)),
#  ('18602938404', (10, 54.577777777777776, 1.5555555555555556)),
#  ('18566472264', (10, 63.9327731092437, 1.7478991596638656)),
#  ('18664564091', (10, 65.90196078431373, 1.7941176470588236)),
#  ('18512006948', (10, 54.214285714285715, 1.7357142857142858)),
#  ('18605879384', (10, 58.72357723577236, 1.6666666666666667)),
#  ('18605873724', (10, 73.80927835051547, 2.051546391752577)),
#  ('18602949964', (10, 63.63709677419355, 1.596774193548387)),
#  ('18605871046', (10, 54.44387755102041, 1.7653061224489797)),
#  ('18657946954', (10, 73.41697416974169, 2.2398523985239853)),
#  ('18691853790', (10, 53.98823529411764, 1.6588235294117648)),
#  ('13216607999', (10, 89.3859649122807, 1.1754385964912282)),
#  ('18605876894', (10, 57.96078431372549, 1.8774509803921569)),
#  ('18626831564', (10, 63.161764705882355, 1.9080882352941178)),
#  ('18698394624', (10, 73.93820224719101, 2.0)),
#  ('18668056546', (10, 42.95192307692308, 1.3942307692307692)),
#  ('18691012724', (10, 53.663366336633665, 1.5643564356435644)),
#  ('18626839410', (10, 67.26639344262296, 1.9221311475409837)),
#  ('18512006874', (10, 61.66233766233766, 1.9610389610389611)),
#  ('18626835741', (10, 50.06015037593985, 1.6165413533834587)),
#  ('18575251327', (10, 51.278481012658226, 1.8227848101265822)),
#  ('18626835841', (10, 61.32231404958678, 1.9421487603305785)),
#  ('18650294604', (10, 79.53669724770643, 2.279816513761468)),
#  ('18512099384', (10, 50.65605095541401, 1.6114649681528663)),
#  ('18657948074', (10, 67.04089219330855, 2.1561338289962824)),
#  ('18659034524', (10, 64.51813471502591, 2.010362694300518)),
#  ('18512099674', (10, 51.770270270270274, 1.7162162162162162)),
#  ('18605872416', (10, 62.584210526315786, 1.8894736842105264)),
#  ('18659014874', (10, 66.20994475138122, 1.9723756906077348)),
#  ('18626834139', (10, 68.66423357664233, 2.0072992700729926)),
#  ('18605879487', (10, 72.21702127659574, 2.2))]

# %%
rdd43 = rdd42.map(lambda x:(x[0],x[1][0]))

# %%
top10000 = rdd43.take(100000)

# %%
len(top10000)
# Out:
# 10000

# %%
top10000[-10:]
# Out:
# [('13817011859', 1),
#  ('17134710360', 1),
#  ('15143529889', 1),
#  ('13589803122', 1),
#  ('13417223333', 1),
#  ('18677412971', 1),
#  ('15267947009', 1),
#  ('18617344965', 1),
#  ('13134668577', 1),
#  ('13394933011', 1)]

# %%
over10000 = set([x for x,y in top10000])
